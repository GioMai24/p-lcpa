# %%
import os
import pandas as pd
import matplotlib.pyplot as plt


fame = {}
for i in os.listdir('data/GC_chi01_output_noclusterevolv/'):
    name = 'data/GC_chi01_output_noclusterevolv/' + str(i) + '/nth_generation.txt'
    fame[str(i)] = pd.read_csv(name, delimiter=' ', skiprows=1, header=None)
    fame[str(i)].drop(fame[str(i)].columns[[5, 6, 7, 8, 10, 11, 12, 14, 18, 19, 20, 21, 22, 23, 24, 26]], axis=1, inplace=True)
display(fame['0.012'])
# Out:
#            0           1           2         3         4           9   \
# 0          72   42.863267   12.057043  0.717502  0.149036  307.174987
# 1         136   30.956327   27.832721  0.737173  0.109740   77.422376
# 2         191   28.549238   22.475507  0.728393  0.119595  824.444908
# 3         209   66.674765   37.303653  0.735199  0.097003  105.364148
# 4         213   20.205933   19.630820  0.717912  0.142823  258.262021
# ...       ...         ...         ...       ...       ...         ...
# 22981   48840  214.631257  141.959145  0.920027  0.896051   37.270786
# 22982  139141   42.676242   33.671857  0.888157  0.086193  128.235105
# 22983  161086   32.641974   18.349185  0.850081  0.152584  191.366604
# 22984  189050   56.344341   49.130588  0.896051  0.107550  319.126388
# 22985  582093   47.255201   39.364534  0.838020  0.137850   48.086861
#
#                  13          15        16          17            25  27
# ...
